# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import signal

# %%
def salvartxt(nome, arrt, arry):
    with open(f'transformadas/{nome}.txt', 'w') as f:
        for linha in range(len(arrt)):
            f.write(f'{arrt[linha]}\t{arry[linha]}\n')

# %%
plt.rcParams['figure.figsize'] = [15,40]
plt.rcParams['font.size'] = 13

n = 2500
T = 150e3 * 2 * np.pi
x = np.array(np.linspace(-1.48e-5, 3.518e-5, n))
a = 235
y1 = a * signal.square(x*T) - 200

y_exp = np.loadtxt('curva_original.txt')
t = y_exp[:,0]
y2 = y_exp[:,1]

# Transformada quadrada
fft1 = np.fft.fft(y1)
freqs1 = np.fft.fftfreq(n, t[1] - t[0])

# Transformada original
fft2 = np.fft.fft(y2)
freqs2 = np.fft.fftfreq(n, t[1] - t[0])

plt.subplot(6,1,1)
plt.plot(t, y1)
plt.plot(t, y2)
plt.grid()

plt.subplot(6,1,2)
plt.plot(np.abs(freqs1[0:300]), np.abs(fft1[0:300]), np.abs(freqs2[0:300]), np.abs(fft2[0:300]))
plt.legend(('FFT Quadrada', 'FFT Original'))
plt.grid()

# Crista do sinal

d1 = 80 #ponto inicial (80)
d2 = 210 #ponto final (210)

ycris = y_exp[d1:d2,1]
tcris = y_exp[d1:d2,0]

fftCris = np.fft.fft(ycris)
freqsCris = np.fft.fftfreq(len(ycris), t[1] - t[0])

plt.subplot(6,1,3)
plt.plot(tcris, ycris, label='ycris')
plt.legend()
plt.grid()

plt.subplot(6,1,4)
plt.plot(np.abs(freqsCris), np.abs(fftCris), color='r')
plt.grid()

# Soma do sinal com a crista

#Sfft = fft1 + fftCris
#Sifft = np.fft.ifft(Sfft)

#plt.subplot(6,1,5)
#plt.plot(np.abs(freqs1), np.abs(Sfft), label='FFT somada')
#plt.legend()
#plt.grid()

#plt.subplot(6,1,6)
#plt.plot(Sifft, label='FFT somada inversa')
#plt.legend()
#plt.grid()


salvartxt('FFTQuadrado', np.abs(freqs1), np.abs(fft1))
salvartxt('FFTOriginal', np.abs(freqs2), np.abs(fft2))
salvartxt('FFTCrista', np.abs(freqsCris), np.abs(fftCris))

# %%
plt.rcParams['figure.figsize'] = [15,6]

plt.plot(tcris,np.fft.ifft(fftCris))
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
