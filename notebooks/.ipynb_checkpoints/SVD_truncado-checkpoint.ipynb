# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize'] = [16, 8]


A = imread(os.path.join('test.jpg'))
X = np.mean(A, -1); # Uma imagem RGB são três matrizes. O -1 significa que está fazendo uma média sobre as cores

img = plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=False)

# Print de teste
print(f""" 
X: {X.shape}
U: {U.shape}
S: {S.shape}
VT: {VT.shape}
""")

S = np.diag(S)

j = 0
for r in (5, 20, 100):
    # Construct approximate image
    Xapprox = U[:,:r] @ S[0:r,:r] @ VT[:r,:] #Este me parece o mehor jeito de multiplicar matrizes
    plt.figure(j+1)
    j += 1
    img = plt.imshow(Xapprox)
    img.set_cmap('gray')
    plt.axis('off')
    plt.title('r = ' + str(r))
    plt.show()
# Out:
#
# X: (4912, 3264)
# U: (4912, 3264)
# S: (3264,)
# VT: (3264, 3264)

# %%
plt.figure(1)
plt.semilogy(np.diag(S))
plt.title('Singular Values')
plt.show()

plt.figure(2)
plt.plot(np.cumsum(np.diag(S))/np.sum(np.diag(S)))
plt.title('Singular Values: Cumulative Sum')
plt.show()
