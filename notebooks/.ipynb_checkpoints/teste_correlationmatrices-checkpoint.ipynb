# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os, PIL

# %%
A = imread(os.path.join('images/gato.jpg'))
X = np.mean(A, -1)
img_test = plt.imshow(X)
img_test.set_cmap("gray")
plt.figure("gato")
plt.show()

# complexo conjugado de X: np.conj(X).T

U, S, V = np.linalg.svd(X, full_matrices=False)
S = np.diag(S)

cmaps = [
    'viridis', 'plasma', 'inferno', 'magma', 'cividis', 'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr',
    'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu', 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn', 'binary', 'gist_yarg', 
    'gist_gray', 'gray', 'bone', 'pink','spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia','hot', 'afmhot', 'gist_heat', 
    'copper','PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu','RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic',
    'twilight', 'twilight_shifted', 'hsv','Pastel1', 'Pastel2', 'Paired', 'Accent','Dark2', 'Set1', 'Set2', 'Set3','tab10', 
    'tab20', 'tab20b', 'tab20c','flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern','gnuplot', 'gnuplot2', 
    'CMRmap', 'cubehelix', 'brg','gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral','gist_ncar'
      ]

print(f"""
X = {X.shape};
U = {U.shape};
S = {S.shape};
V = {V.shape}
""")
# Out:
# X = (192, 192);
# U = (192, 192);
# S = (192, 192);
# V = (192, 192)

# %%
# colormaps que funcionam: flag; prism

plt.figure("XX*U")
corr1 = X @ np.conj(X).T @ U
img_corr1 = plt.imshow(corr1)
img_corr1.set_cmap('flag')
plt.title('XX*U')
plt.show()

# com o autovalor U
plt.figure("""U [[S**2, 0], [0, 0]]""")
eig1 = U @ S**2
img_eig1 = plt.imshow(eig1)
img_eig1.set_cmap('flag')
plt.title("""U [[S**2, 0], [0, 0]]""")
plt.show()

print('true' if corr1.all == eig1.all else "false")
# Out:
# false

# %%
plt.figure('X*XV')
corr2 = np.conj(X).T @ X @ V
img_corr2 = plt.imshow(corr2)
img_corr2.set_cmap('prism')
plt.title('X*XV')
plt.show()

# com o autovalor V
plt.figure('VS**2')
eig2 = V @ S**2
img_eig2 = plt.imshow(eig2)
img_eig2.set_cmap('prism')
plt.title('VS**2')
plt.show()

print('true' if corr2.all == eig2.all else 'false')
# Out:
# false

# %%
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = [(0 < y) & ( y > 1)]

print(y)
# Out:
# [array([False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
# ...

# %%
for pos, bool in enumerate(y):
    if bool = 'True':
        print(pos, end=", ")
# Out:
# 93
